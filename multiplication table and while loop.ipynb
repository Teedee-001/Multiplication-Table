# %%
for i in range(1, 13):
    print(f"\nMultiplication Table for", i)
    for j in range(1, 13):
        print(f"{i} × {j} = {i * j}")
# Out:
# Multiplication Table for 1
# 1 × 1 = 1
# 1 × 2 = 2
# 1 × 3 = 3
# 1 × 4 = 4
# 1 × 5 = 5
# 1 × 6 = 6
# 1 × 7 = 7
# 1 × 8 = 8
# 1 × 9 = 9
# 1 × 10 = 10
# 1 × 11 = 11
# 1 × 12 = 12
#
# Multiplication Table for 2
# 2 × 1 = 2
# 2 × 2 = 4
# 2 × 3 = 6
# 2 × 4 = 8
# 2 × 5 = 10
# 2 × 6 = 12
# 2 × 7 = 14
# 2 × 8 = 16
# 2 × 9 = 18
# 2 × 10 = 20
# 2 × 11 = 22
# 2 × 12 = 24
#
# Multiplication Table for 3
# 3 × 1 = 3
# 3 × 2 = 6
# 3 × 3 = 9
# 3 × 4 = 12
# 3 × 5 = 15
# 3 × 6 = 18
# 3 × 7 = 21
# 3 × 8 = 24
# 3 × 9 = 27
# 3 × 10 = 30
# 3 × 11 = 33
# 3 × 12 = 36
#
# Multiplication Table for 4
# 4 × 1 = 4
# 4 × 2 = 8
# 4 × 3 = 12
# 4 × 4 = 16
# 4 × 5 = 20
# 4 × 6 = 24
# 4 × 7 = 28
# 4 × 8 = 32
# 4 × 9 = 36
# 4 × 10 = 40
# 4 × 11 = 44
# 4 × 12 = 48
#
# Multiplication Table for 5
# 5 × 1 = 5
# 5 × 2 = 10
# 5 × 3 = 15
# 5 × 4 = 20
# 5 × 5 = 25
# 5 × 6 = 30
# 5 × 7 = 35
# 5 × 8 = 40
# 5 × 9 = 45
# 5 × 10 = 50
# 5 × 11 = 55
# 5 × 12 = 60
#
# Multiplication Table for 6
# 6 × 1 = 6
# 6 × 2 = 12
# 6 × 3 = 18
# ...

# %%
David = 17
while David >= 17:
    print("David's age is ", David)
    David = David +1
# Out:
# David's age is  17
# David's age is  18
# David's age is  19
# David's age is  20
# David's age is  21
# David's age is  22
# David's age is  23
# David's age is  24
# David's age is  25
# David's age is  26
# David's age is  27
# David's age is  28
# David's age is  29
# David's age is  30
# David's age is  31
# David's age is  32
# David's age is  33
# David's age is  34
# David's age is  35
# David's age is  36
# David's age is  37
# David's age is  38
# David's age is  39
# David's age is  40
# David's age is  41
# David's age is  42
# David's age is  43
# David's age is  44
# David's age is  45
# David's age is  46
# David's age is  47
# David's age is  48
# David's age is  49
# David's age is  50
# David's age is  51
# David's age is  52
# David's age is  53
# David's age is  54
# David's age is  55
# David's age is  56
# David's age is  57
# David's age is  58
# David's age is  59
# David's age is  60
# David's age is  61
# David's age is  62
# David's age is  63
# ...

# %%
year = 2025
while year >=2025:
    print("The upcoming year is:", year)
    year = year + 1
# Out:
# The upcoming year is: 2025
# The upcoming year is: 2026
# The upcoming year is: 2027
# The upcoming year is: 2028
# The upcoming year is: 2029
# The upcoming year is: 2030
# The upcoming year is: 2031
# The upcoming year is: 2032
# The upcoming year is: 2033
# The upcoming year is: 2034
# The upcoming year is: 2035
# The upcoming year is: 2036
# The upcoming year is: 2037
# The upcoming year is: 2038
# The upcoming year is: 2039
# The upcoming year is: 2040
# The upcoming year is: 2041
# The upcoming year is: 2042
# The upcoming year is: 2043
# The upcoming year is: 2044
# The upcoming year is: 2045
# The upcoming year is: 2046
# The upcoming year is: 2047
# The upcoming year is: 2048
# The upcoming year is: 2049
# The upcoming year is: 2050
# The upcoming year is: 2051
# The upcoming year is: 2052
# The upcoming year is: 2053
# The upcoming year is: 2054
# The upcoming year is: 2055
# The upcoming year is: 2056
# The upcoming year is: 2057
# The upcoming year is: 2058
# ...
